# %% [markdown]
# ##### Alphavantage search call:
# https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=Micro&apikey=demo

# %%
import requests
import pandas as pd
from IPython.display import display

# %%
# replace this string with your API key
# request one to www.alphavantage.co if you don't have one
API_KEY='your_API_key_here'

# %%
_BASE_URL = 'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords='
_API_KEY_URL = '&apikey='

# %%
search = input('Search string: ')
url = _BASE_URL + search +_API_KEY_URL + API_KEY
response = requests.get(url)
json_response = response.json()

# delete results if exists from previous call
try:
    del results
except:
    pass

if len(json_response['bestMatches']) > 0:
    for item in json_response['bestMatches']:
        # append rows if dataframe exists already, otherwise creates it
        try:
            results = results.append(pd.DataFrame(pd.Series(item)).transpose())
        except:
            results = pd.DataFrame(pd.Series(item)).transpose()
    display(results)
else:
    print('Nothing found')
# Out:
# Search string: aapl
#     1. symbol     2. name 3. type         4. region 5. marketOpen  \
# 0        AAPL  Apple Inc.  Equity     United States         09:30
# 0    AAPL.MEX  Apple Inc.  Equity            Mexico         08:30
# 0  AAPL34.SAO  Apple Inc.  Equity  Brazil/Sao Paolo         10:00
# 0    AAPL.ARG  Apple Inc.  Equity         Argentina         11:00
# 0    AAPL.SWI  Apple Inc.  Equity       Switzerland         09:00
# 0    AAPL.VIE  Apple Inc.  Equity            Vienna         08:55
# 0    AAPL.SAN  Apple Inc.  Equity    Chile/Santiago         09:30
# 0    AAPL.MIL       APPLE  Equity             Milan         09:00
#
#   6. marketClose 7. timezone 8. currency 9. matchScore
# 0          16:00      UTC-05         USD        1.0000
# 0          15:00      UTC-06         MXP        0.7273
# 0          17:30      UTC-02         BRL        0.7273
# 0          17:00      UTC-03         ARS        0.7273
# 0          17:30      UTC+01         CHF        0.7273
# ...
